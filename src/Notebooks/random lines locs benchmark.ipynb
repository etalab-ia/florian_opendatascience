# %%
import numpy as np
import random
import pandas as pd

# %%
randlist=random.sample(range(1, 42800), 500)

# %%
randlist
# Out:
# [13342,
#  12028,
#  25751,
#  35424,
#  13583,
#  3400,
#  25282,
#  11957,
#  21856,
#  5388,
#  13741,
#  9176,
#  1923,
#  17299,
#  20355,
#  13154,
#  8980,
#  2566,
#  5550,
#  27738,
#  16565,
#  522,
#  21766,
#  17866,
#  16510,
#  21977,
#  19413,
#  18190,
#  9776,
#  6729,
#  17382,
#  38792,
#  14222,
#  18327,
#  15645,
#  26872,
#  38294,
#  20426,
#  36658,
#  21220,
#  12383,
#  1225,
#  13085,
#  23745,
#  1978,
#  6511,
#  9118,
#  30857,
#  10591,
#  35745,
#  9331,
#  17629,
#  36998,
#  6065,
#  724,
#  42240,
#  4768,
#  36263,
#  22785,
#  9953,
#  12616,
#  28423,
#  26705,
#  22772,
#  18597,
#  31758,
#  24893,
#  9491,
#  12470,
#  27731,
#  6969,
#  33255,
#  13222,
#  30689,
#  34180,
#  38430,
#  41617,
#  15132,
#  20298,
#  14240,
#  28091,
#  31499,
#  6339,
#  32978,
#  14266,
#  19237,
#  22756,
#  1754,
#  16442,
#  41058,
#  4958,
#  6386,
#  24555,
#  4251,
#  16067,
#  19626,
#  2038,
#  37695,
#  22830,
#  38542,
#  5421,
#  30627,
#  27047,
# ...

# %%
df=pd.read_csv('../../data/Catalogue_locs.csv', sep=',',error_bad_lines=False, encoding='latin-1') #le fichier original

# %%
df_rand=df.iloc[randlist, [1,2,3,4,5,7,24]]

# %%
df_rand
# Out:
#                              id  \
# 13342  5a980554b59508758b84c020
# 12028  5b55e3fac751df1614be7308
# 25751  584ecf1ac751df202dc0bb7e
# 35424  55896ecfc751df3fd2a453c2
# 13583  5a6c432fb595085a47a2256a
# ...                         ...
# 5673   5cf858b406e3e710d9c3f006
# 16490  5a099819c751df0f5833ee60
# 31281  56a799c888ee387c68822417
# 20744  5912c93688ee3879b583cbd8
# 7463   5c77dd2d9ce2e718441da1b8
#
#                                                    title  \
# 13342                  Zonage du r̩seau des eaux us̩es
# 12028                          Point d'apport volontaire
# 25751     Liste des compl̩ments alimentaires d̩clar̩s
# 35424       Prescription surfacique du POS de Les Riceys
# 13583               Parkings (test - contribution libre)
# ...                                                  ...
# 5673                                Caniparcs - Toulouse
# 16490  Gestionnaire des servitudes PM1 pour le d̩par...
# ...

# %%
df_rand.to_csv('../../data/locs_benchmark.csv')
